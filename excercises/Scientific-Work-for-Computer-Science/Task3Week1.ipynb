# %% [markdown]
# Task #3
# Based on the above exercises and your previous background, identify the research problem you want to work on in this semester? What is current state-of-the-art and on which aspect you want to work? What bar you want to raise?
