# %% [markdown]
# Task #2
# Based on the learning during the lecture about how to read a paper quickly, read three good papers of your area and make a report, answering the following questions:
# (a)	What is the main topic of the paper?
# (b)	What was the current state-of-the-art?
# (c)	What was the methodology of the paper to solve the problem?
# (d)	What were the results and evaluations with the state-of-the-art?
