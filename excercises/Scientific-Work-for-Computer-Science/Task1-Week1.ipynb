# %% [markdown]
# Task #1
# Based on the learning in the first lecture of the module:
# (1)	Identify the good journals and conferences of your area
# (2)	Identify good papers in your area and discuss with the instructor
